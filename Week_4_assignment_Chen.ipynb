# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets

# %%
dataset = pd.read_csv("https://github.com/UIUC-iSchool-DataViz/is445_AOUAOG_fall2021/raw/master/week05/data/ufo-scrubbed-geocoded-time-standardized-00.csv ")

# %%
dataset
# Out:
#        10/10/1949 20:30            san marcos   tx   us cylinder    2700  \
# 0      10/10/1949 21:00          lackland afb   tx  NaN    light  7200.0
# 1      10/10/1955 17:00  chester (uk/england)  NaN   gb   circle    20.0
# 2      10/10/1956 21:00                  edna   tx   us   circle    20.0
# 3      10/10/1960 20:00               kaneohe   hi   us    light   900.0
# 4      10/10/1961 19:00               bristol   tn   us   sphere   300.0
# ...                 ...                   ...  ...  ...      ...     ...
# 80326    9/9/2013 21:15             nashville   tn   us    light   600.0
# 80327    9/9/2013 22:00                 boise   id   us   circle  1200.0
# 80328    9/9/2013 22:00                  napa   ca   us    other  1200.0
# 80329    9/9/2013 22:20                vienna   va   us   circle     5.0
# 80330    9/9/2013 23:00                edmond   ok   us    cigar  1020.0
#
#        45 minutes  \
# 0         1-2 hrs
# 1      20 seconds
# 2        1/2 hour
# ...

# %%
dataset.columns = ['date','city','state','country','shape','duration_seconds','duration','comment','report_date','latitude','longitude']
dataset
# Out:
#                    date                  city state country   shape  \
# 0      10/10/1949 21:00          lackland afb    tx     NaN   light
# 1      10/10/1955 17:00  chester (uk/england)   NaN      gb  circle
# 2      10/10/1956 21:00                  edna    tx      us  circle
# 3      10/10/1960 20:00               kaneohe    hi      us   light
# 4      10/10/1961 19:00               bristol    tn      us  sphere
# ...                 ...                   ...   ...     ...     ...
# 80326    9/9/2013 21:15             nashville    tn      us   light
# 80327    9/9/2013 22:00                 boise    id      us  circle
# 80328    9/9/2013 22:00                  napa    ca      us   other
# 80329    9/9/2013 22:20                vienna    va      us  circle
# 80330    9/9/2013 23:00                edmond    ok      us   cigar
#
#        duration_seconds    duration  \
# 0                7200.0     1-2 hrs
# 1                  20.0  20 seconds
# 2                  20.0    1/2 hour
# ...

# %%
df = dataset.fillna({'country':'unknown', 'state': 'unknown', 'shape':'unknown'})
df
# Out:
#                    date                  city    state  country   shape  \
# 0      10/10/1949 21:00          lackland afb       tx  unknown   light
# 1      10/10/1955 17:00  chester (uk/england)  unknown       gb  circle
# 2      10/10/1956 21:00                  edna       tx       us  circle
# 3      10/10/1960 20:00               kaneohe       hi       us   light
# 4      10/10/1961 19:00               bristol       tn       us  sphere
# ...                 ...                   ...      ...      ...     ...
# 80326    9/9/2013 21:15             nashville       tn       us   light
# 80327    9/9/2013 22:00                 boise       id       us  circle
# 80328    9/9/2013 22:00                  napa       ca       us   other
# 80329    9/9/2013 22:20                vienna       va       us  circle
# 80330    9/9/2013 23:00                edmond       ok       us   cigar
#
#        duration_seconds    duration  \
# 0                7200.0     1-2 hrs
# ...

# %%
stats = df_corrected["country"].value_counts()
stats
# Out:
# us         65113
# unknown     9670
# ca          3000
# gb          1905
# au           538
# de           105
# Name: country, dtype: int64

# %%
stats.index
# Out:
# Index(['us', 'unknown', 'ca', 'gb', 'au', 'de'], dtype='object')

# %%
stats.values
# Out:
# array([65113,  9670,  3000,  1905,   538,   105], dtype=int64)

# %%
@ipywidgets.interact(style = plt.style.available)
def make_plot(style):  
    with plt.style.context(style):
        fig,UFO = plt.plot(stats.index, stats.values)
        UFO.set_xlabel("Country")
        UFO.set_ylabel("Number of Report")
    plt.show
# Out:
# interactive(children=(Dropdown(description='style', options=('Solarize_Light2', '_classic_test_patch', 'bmh', …
